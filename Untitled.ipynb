# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
registro_1 = pd.read_excel('df2.xlsx')
registro_2 = pd.read_excel('df2_seg.xlsx')

# %%
registro_2
# Out:
#       Unnamed: 0          rubro                   articulo    cantidad  \
# 0              1  aderezos (12)    Ketchup Hellmanns x 250        4.00
# 1              2  aderezos (12)       Ketchup Hellmans 60g        8.00
# 2              3  aderezos (12)  Mayonesa BC oliva 250 cm3        1.00
# 3              4  aderezos (12)         Mayonesa Hellmanns       40.00
# 4              5  aderezos (12)    Mayonesa Hellmanns 125g       29.00
# ...          ...            ...                        ...         ...
# 2063        2107     yerba (10)           Yerba Union 500g        2.00
# 2064        2108     yerba (10)          Yerba union suavb       18.00
# 2065        2109     yerba (10)          Yerba Unión Suave       29.00
# 2066        2110     yerba (10)          Total Rubro yerba      401.00
# 2067        2111         Total                         NaN  2473755.93
#
#            final         costo          neto      margen
# 0          66.00  4.500000e+01     66.000000   46.666667
# ...

# %%
registro_1
# Out:
#       Unnamed: 0          rubro                          articulo  \
# 0              0  aderezos (12)                               NaN
# 1              1  aderezos (12)   Chimichurri picante vanoli 190g
# 2              2  aderezos (12)               Danica ketchup 220g
# 3              3  aderezos (12)       dos ancas chimichurri 380gr
# 4              4  aderezos (12)           Ketchup Hellmanns x 250
# ...          ...            ...                               ...
# 1712        1712     yerba (10)       Yerba verde flor Menta 500g
# 1713        1713     yerba (10)        Yerba verdeflor boldo 500g
# 1714        1714     yerba (10)  Yerba verdeflor hierbas serranas
# 1715        1715     yerba (10)                 Total Rubro yerba
# 1716        1716         Total                                NaN
#
#           cantidad         final         costo          neto     margen
# 0              NaN           NaN           NaN           NaN        NaN
# ...

# %%
registro_1.rename(columns= {'Unnamed: 0': 'Index', 'Artículo': 'rubro', 'Cantidad': 'articulo', 'Final':'1','Costo':'2', 'Neto':'cantidad', 'Margen': 'final', 
          'Unnamed: 6':'costo', 'Unnamed: 7': 'neto', 'Unnamed: 8':'margen'}, inplace= True)
registro_2.rename(columns= {'Unnamed: 0': 'Index', 'Artículo': 'rubro', 'Cantidad': 'articulo', 'Final':'1','Costo':'2', 'Neto':'cantidad', 'Margen': 'final', 
          'Unnamed: 6':'costo', 'Unnamed: 7': 'neto', 'Unnamed: 8':'margen'}, inplace= True)

# %%
registro_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1717 entries, 0 to 1716
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Index     1717 non-null   int64
#  1   rubro     1717 non-null   object
#  2   articulo  1673 non-null   object
#  3   cantidad  1674 non-null   float64
#  4   final     1674 non-null   float64
#  5   costo     1674 non-null   float64
#  6   neto      1674 non-null   float64
#  7   margen    1673 non-null   float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 107.4+ KB

# %%
registro_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2068 entries, 0 to 2067
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Index     2068 non-null   int64
#  1   rubro     2068 non-null   object
#  2   articulo  2067 non-null   object
#  3   cantidad  2068 non-null   float64
#  4   final     2068 non-null   float64
#  5   costo     2068 non-null   float64
#  6   neto      2068 non-null   float64
#  7   margen    2067 non-null   float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 129.4+ KB

# %%
reg_final = pd.concat([registro_1, registro_2 ], axis= 'index')

# %%
reg_final
# Out:
#       Index          rubro                         articulo    cantidad  \
# 0         0  aderezos (12)                              NaN         NaN
# 1         1  aderezos (12)  Chimichurri picante vanoli 190g        1.00
# 2         2  aderezos (12)              Danica ketchup 220g        4.00
# 3         3  aderezos (12)      dos ancas chimichurri 380gr        1.00
# 4         4  aderezos (12)          Ketchup Hellmanns x 250       15.00
# ...     ...            ...                              ...         ...
# 2063   2107     yerba (10)                 Yerba Union 500g        2.00
# 2064   2108     yerba (10)                Yerba union suavb       18.00
# 2065   2109     yerba (10)                Yerba Unión Suave       29.00
# 2066   2110     yerba (10)                Total Rubro yerba      401.00
# 2067   2111         Total                               NaN  2473755.93
#
#            final         costo          neto     margen
# ...

# %%
reg_final.reset_index()
# Out:
#       index  Index          rubro                         articulo  \
# 0         0      0  aderezos (12)                              NaN
# 1         1      1  aderezos (12)  Chimichurri picante vanoli 190g
# 2         2      2  aderezos (12)              Danica ketchup 220g
# 3         3      3  aderezos (12)      dos ancas chimichurri 380gr
# 4         4      4  aderezos (12)          Ketchup Hellmanns x 250
# ...     ...    ...            ...                              ...
# 3780   2063   2107     yerba (10)                 Yerba Union 500g
# 3781   2064   2108     yerba (10)                Yerba union suavb
# 3782   2065   2109     yerba (10)                Yerba Unión Suave
# 3783   2066   2110     yerba (10)                Total Rubro yerba
# 3784   2067   2111         Total                               NaN
#
#         cantidad       final         costo          neto     margen
# 0            NaN         NaN           NaN           NaN        NaN
# ...

# %%
reg_final.insert(0, column= 'INDEX', value= range(0,3785,1))

# %%
reg_final.set_index('INDEX', inplace= True)

# %%
reg_final.replace('Cigarrillos (2)','cigarrillos', inplace= True)
reg_final.replace('Generico (1)','generico', inplace= True)
reg_final.replace('Golosinas (2)','golosinas', inplace= True)
reg_final.replace('Helados (1.504)','helados', inplace= True)
reg_final.replace('Krachitos','kranchitos', inplace= True)
reg_final.replace('Golosinas (3)','golosinas', inplace= True)
reg_final.replace('9327800004825','encendedores', inplace= True)

# %%
reg_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3785 entries, 0 to 3784
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Index     3785 non-null   int64
#  1   rubro     3785 non-null   object
#  2   articulo  3740 non-null   object
#  3   cantidad  3742 non-null   float64
#  4   final     3742 non-null   float64
#  5   costo     3742 non-null   float64
#  6   neto      3742 non-null   float64
#  7   margen    3740 non-null   float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 266.1+ KB

# %%
reg_final.drop(columns=['Index'], inplace= True)

# %%
reg_final
# Out:
#                rubro                         articulo    cantidad       final  \
# INDEX
# 0      aderezos (12)                              NaN         NaN         NaN
# 1      aderezos (12)  Chimichurri picante vanoli 190g        1.00      130.00
# 2      aderezos (12)              Danica ketchup 220g        4.00      480.00
# 3      aderezos (12)      dos ancas chimichurri 380gr        1.00      340.00
# 4      aderezos (12)          Ketchup Hellmanns x 250       15.00     2870.00
# ...              ...                              ...         ...         ...
# 3780      yerba (10)                 Yerba Union 500g        2.00       66.00
# 3781      yerba (10)                Yerba union suavb       18.00      576.00
# 3782      yerba (10)                Yerba Unión Suave       29.00      986.00
# 3783      yerba (10)                Total Rubro yerba      401.00    13263.50
# 3784          Total                               NaN  2473755.93  1089949.62
#
# ...

# %%
reg_final.sort_values(by=['rubro'], inplace= True)

# %%
reg_final
# Out:
#                          rubro                           articulo    cantidad  \
# INDEX
# 4179                    Total                                 NaN  2473755.93
# 2111                    Total                                 NaN  2473755.93
# 726    Total Rubro Cigarrillos                                NaN    38162.00
# 2823   Total Rubro Cigarrillos                                >>>    38162.00
# 1458      Total Rubro Generico                                NaN     7247.00
# ...                        ...                                ...         ...
# 2095                yerba (10)                                NaN         NaN
# 2107                yerba (10)                   Yerba Union 500g        2.00
# 2105                yerba (10)             Yerba Rosamonte x 500g        2.00
# 4164                yerba (10)  Botella termica taragui (termito)        1.00
# 2104                yerba (10)        Yerba Rosamonte suave x 250        3.00
#
# ...

# %%
reg_final.to_excel('df_sumados.xlsx')

# %%
reg_final
# Out:
#                          rubro                           articulo    cantidad  \
# INDEX
# 4179                    Total                                 NaN  2473755.93
# 2111                    Total                                 NaN  2473755.93
# 726    Total Rubro Cigarrillos                                NaN    38162.00
# 2823   Total Rubro Cigarrillos                                >>>    38162.00
# 1458      Total Rubro Generico                                NaN     7247.00
# ...                        ...                                ...         ...
# 2095                yerba (10)                                NaN         NaN
# 2107                yerba (10)                   Yerba Union 500g        2.00
# 2105                yerba (10)             Yerba Rosamonte x 500g        2.00
# 4164                yerba (10)  Botella termica taragui (termito)        1.00
# 2104                yerba (10)        Yerba Rosamonte suave x 250        3.00
#
# ...
